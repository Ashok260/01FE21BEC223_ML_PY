# %% [markdown]
# Q8)

# %%
n=int(input("Enter number of rows"))
for i in range(n):
  print("*i")

# %% [markdown]
# Q7

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
n=int(input("Enter number of elements to be entered into the list"))
a=[]
even=[]
odd=[]
for i in range(n):
  b=int(input("enter the number"))
  a.append(b)
  if(b%2==0):
   even.append(b)
  else:
    odd.append(b)
print(a)
plt.plot(a)
plt.show()
print("Even numbers list = ",even)
print("Odd numbers list =",odd)
# Out:
# Enter number of elements to be entered into the list10
# enter the number3
# enter the number4
# enter the number6
# enter the number5
# enter the number2
# enter the number7
# enter the number6
# enter the number8
# enter the number8
# enter the number25
# [3, 4, 6, 5, 2, 7, 6, 8, 8, 25]
# Even numbers list =  [4, 6, 2, 6, 8, 8]
# Odd numbers list = [3, 5, 7, 25]

# %% [markdown]
# Q6)string is palindrome or not

# %%
string=input("Enter the string")
c=0
l=int(len(string))
n=l
a=list(string)
print(type(a))
b=a
d=1
for i in a:
  if(a[d-1]==b[l-d]):
    c=c+1
    d=d+1
  else:
    break
if(c==l):
  print("string is palindrome")
else:
  print("String is not palindrome")
# Out:
# Enter the stringgadag
# <class 'list'>
# string is palindrome

# %% [markdown]
# Q5)

# %%
n=int(input("Enter the number")
if(n%2==0 or n%9==0)):
  print("number is not prime")
  if(n%3==0 or n%7==0 or n%9==0 or n%11==0):
    print("N is divisible")
else:
  print("n is prime")
# Out:
#   File "<ipython-input-28-6a3afcafbba5>", line 1
#     n=int(input("Enter the number")
#           ^
# SyntaxError: expected 'else' after 'if' expression
